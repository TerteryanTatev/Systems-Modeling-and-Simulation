# %% [markdown]
# <a href="https://colab.research.google.com/github/TerteryanTatev/Systems-Modeling-and-Simulation/blob/main/Polynomial-Interpolation-Lagrange/lagrange_interpolationipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
qqimport numpy as np
import pandas as pd
import sympy as sp

# %%
df = pd.DataFrame({
    'Xi': [ i/100 for i in range(350, 421, 5)],
    'fi': [33.11, 34.81, 36.59, 38.47, 40.44, 42.52, 44.70, 46.99, 49.40, 51.93, 54.59, 57.39, 60.34, 63.43, 66.68]})
df
# Out:
#       Xi     fi
# 0   3.50  33.11
# 1   3.55  34.81
# 2   3.60  36.59
# 3   3.65  38.47
# 4   3.70  40.44
# 5   3.75  42.52
# 6   3.80  44.70
# 7   3.85  46.99
# 8   3.90  49.40
# 9   3.95  51.93
# 10  4.00  54.59
# 11  4.05  57.39
# 12  4.10  60.34
# 13  4.15  63.43
# 14  4.20  66.68

# %%
x = df["Xi"].to_list()
y = df["fi"].to_list()


def f(i, j):

    if i == j:
        return y[i]
    return (f(i+1, j) - f(i, j-1)) / (x[j] - x[i])
print(x)
print(y)
# Out:
# [3.5, 3.55, 3.6, 3.65, 3.7, 3.75, 3.8, 3.85, 3.9, 3.95, 4.0, 4.05, 4.1, 4.15, 4.2]
# [33.11, 34.81, 36.59, 38.47, 40.44, 42.52, 44.7, 46.99, 49.4, 51.93, 54.59, 57.39, 60.34, 63.43, 66.68]

# %%
def N3(X):
    return f(0,0) + (X - x[0]) * f(0,1) +  (X - x[0]) *  (X - x[1]) *  f(0,2) + (X - x[0]) *  (X - x[1]) * (X - x[2]) * f(0,3)

print( 'N(0.1175)=', N3(3.522))
print( 'N(0.1773)=', N3(4.176))
print( 'N(0.1134)=', N3(3.47))
print( 'N(0.190)=', N3(4.25))
N3(3.85)
# Out:
# N(0.1175)= 33.84942528
# N(0.1773)= 69.36479936000775
# N(0.1134)= 32.12007999999998
# N(0.190)= 76.11000000001106
# 47.39000000000068

# %%
X = sp.Symbol('x')
fun = f(0, 0)
for i in range(1, len(x)):
    t = f(0, i)
    for j in range(i):
        t *= (X - x[j])
    fun += t

sp.expand(fun)
# Out:
# 14471125.5832328*x**14 - 762562540.393946*x**13 + 18639773396.669*x**12 - 280120530190.021*x**11 + 2891340229494.59*x**10 - 21682607749644.3*x**9 + 121822636038891.0*x**8 - 520917195300956.0*x**7 + 1.70344442249027e+15*x**6 - 4.23903915839989e+15*x**5 + 7.90173626575761e+15*x**4 - 1.06979796320251e+16*x**3 + 9.94375091530314e+15*x**2 - 5.67947812284556e+15*x + 1.50375816103434e+15
